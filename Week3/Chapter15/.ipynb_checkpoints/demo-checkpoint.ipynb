# %%
x = seq(-10, 10, by=.1)

# %%
y = dnorm(x, mean =0, sd =1)

# %%
plot(x ,y)
# Out:
# plot without title

# %%
length(x)
# Out:
# [1] 201

# %%
y = pnorm(x, mean=0, sd =1)

# %%
plot(x,y)
# Out:
# plot without title
