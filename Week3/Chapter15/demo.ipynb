# %%
x = seq(-10, 10, by=.1)

# %%
y = dnorm(x, mean =0, sd =1)

# %%
plot(x ,y)
# Out:
# plot without title

# %%
length(x)
# Out:
# [1] 201

# %%
y = pnorm(x, mean=0, sd =1)

# %%
plot(x,y)
# Out:
# plot without title

# %%
x7 = pnorm(7, mean=0, sd=1)
x7
# Out:
# [1] 1

# %%
p = pnorm(1.75, mean=1.63, sd=0.05)
p
# Out:
# [1] 0.9918025

# %%
x = seq(0,1, by=0.02)

# %%
y=qnorm(x, mean=0, sd=1)

# %%
plot(x,y)
# Out:
# plot without title

# %%
y =rnorm(50)
print(y)
# Out:
#  [1]  0.651179408  0.698101052 -0.398154994  1.051034228  0.556034789
#  [6]  0.939726820  1.044609914 -0.002923635  0.132311034 -0.289878175
# [11]  2.671284836  0.587224152 -0.486223126 -0.425585454 -0.818998907
# [16] -1.179521557 -0.137663367  1.042299238  0.118808934 -0.808344635
# [21] -0.313426351 -0.934706505 -0.146031536  1.177910887  1.499590643
# [26] -0.158711509  0.460035201 -0.419591456 -0.325272230  0.120338317
# [31] -0.522472223  0.061775598  0.406484595  0.735988101  1.295455705
# [36]  1.215506335  0.193385716  0.570403781  1.081467709  0.267186097
# [41] -1.444032555  0.197616035 -0.306111046  0.300716069  0.385588000
# [46]  1.690370594 -0.828189656  0.746205265 -0.073703333 -1.348092933

# %%
hist(y, main="normal distribution")
# Out:
# Plot with title “normal distribution”

# %%
x = seq(0,50, by=1)
y= dbinom(x, 50, 0.5)

# %%
plot(x,y)
# Out:
# plot without title

# %%
p1 = dbinom(2,3,0.6)
p1
# Out:
# [1] 0.432

# %%
p_x_25_less = pbinom(25, 50, 0.5)
p_x_25_less
# Out:
# [1] 0.5561376

# %%
p_x_25_more = 1- pbinom(24, 50, 0.5)
p_x_25_more
# Out:
# [1] 0.5561376

# %%
x = rbinom(8, 100, 1/6)
print(x)
# Out:
# [1] 16 12 12 18 12 12 13 25
