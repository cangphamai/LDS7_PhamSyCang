# %%
head(AirPassengers)
# Out:
# [1] 112 118 132 129 121 135

# %%
hist(AirPassengers, xlab= "Air Passengers",col= rainbow(length(AirPassengers)))
dev.off()
# Out:
# null device
#           1
# Plot with title “Histogram of AirPassengers”
