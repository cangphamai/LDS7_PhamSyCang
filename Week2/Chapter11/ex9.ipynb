# %%
head(faithful)
# Out:
#   eruptions waiting
# 1 3.600     79
# 2 1.800     54
# 3 3.333     74
# 4 2.283     62
# 5 4.533     85
# 6 2.883     55

# %%
pairs(~eruptions+waiting, data= faithful, main="scatter plot matrix")
dev.off()
# Out:
# null device
#           1
# plot without title

# %%
plot(faithful$eruptions, faithful$waiting, main = "Main title",
     xlab = "X axis title", ylab = "Y axis title",
     pch = 19, frame = FALSE)
# Add regression line
plot(faithful$eruptions, faithful$waiting, main = "Main title",
     xlab = "X axis title", ylab = "Y axis title",
     pch = 19, frame = FALSE)
abline(lm(faithful$waiting~faithful$eruptions), col = "red", lwd = 3)
# Out:
# Plot with title “Main title”
